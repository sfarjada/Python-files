# %%
 import random

def passwordGenerator():
    length = int(input("Enter the length of your password which is greater than 3:"))
    while length <= 3:
        print("Your password length is too low, please enter a length greater than 3.")
        length = int(input("Enter the length of your password which is greater than 3:"))

    combination = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*+=-_\/.'
    password = ''.join(random.choices(combination, k=length))
    print(password)

passwordGenerator()
# Out:
# Enter the length of your password which is greater than 3:3
# Your password length is too low, please enter a length greater than 3.
# Enter the length of your password which is greater than 3:4
# pTQ_

# %%
import random
def userInput():
    passwordLength=int(input("Enter length of password"))
    if(passwordLength<=3):
        print("Your password length is too low, please enter a length greater than 3.")
    else:
       #passwordLength = int(input("Enter the length of your password which is greater than 3: "))
       combination = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*+=-_\/.'
       return passwordGeneratorRec(passwordLength,combination)

def passwordGeneratorRec(passwordLength, combination):
    if passwordLength <= 0:
        return ''
    else:
        char = random.choice(combination)
        return char + passwordGeneratorRec(passwordLength - 1, combination)

userInput()
# Out:
# 'K+k!'
